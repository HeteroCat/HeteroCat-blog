# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.5.1

# %%
import seaborn

print(seaborn.__version__)
# Out:
# 0.11.2

# %%
# %matplotlib inline

# %% [raw]
# 例子

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()  # 创建一个包含一个axes的figure
#axes.plot([1, 2, 3, 4], [1, 4, 2, 3])  # 绘制图像

# %%
import matplotlib.pyplot as plt

figure, axes = plt.subplots()  # 创建一个包含一个axes的figure
axes.plot([1, 2, 3, 4], [1, 4, 2, 3])  # 绘制图像

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %% [raw]
# 基本图表

# %%
#柱状图
import matplotlib.pyplot as plt

plt.bar([1, 2, 3, 4], [1, 4, 2, 3])  # 绘制图像
# Out:
# <BarContainer object of 4 artists>

# %%
#color：支持通过代码快速配置常见的颜色，如r代表红色，blue代表蓝色，也支持十六进制和RGB（A）格式颜色配置；

#width：数值范围0-1，默认0.8；

# %%
plt.bar([1, 2, 3, 4], [1, 4, 2, 3], color=(0.2, 1.0, 1.0), width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
#条形图
plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'   #识别中文

plt.barh(["深圳", "广州", "北京", "上海"], [1, 4, 2, 3])  # 绘制图像
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(["深圳", "广州", "北京", "上海"], [1, 4, 2, 3], height=0.5, color="#0aff00")  # 绘制图像
# Out:
# <BarContainer object of 4 artists>

# %%
#折线图
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])  # 绘制图像

# %% [raw]
# 通过linewidth和linestyle可以进行线宽和线型的配置；
#
# linestyle可接受的参数如下：
#
# linestyle	简写：
# 'solid' 	'-'
# 'dotted'	':'
# 'dashed'	'--'
# 'dashdot'	'-.'
# 'None'	   '' 或 ' '

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3], color='blue', linewidth=2, linestyle='-.')

# %% [markdown]
# 通过marker和makersize可以绘制带标记点的折线图；
#
# 支持的maker样式如下：
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3], color='blue', linewidth=2, linestyle='-.', marker='*', markersize=15)

# %%
#面积图
plt.stackplot([1, 2, 3, 4], [1, 4, 2, 3], color=(0.4, 0.2, 0.1, 0.1))

# %%
#饼图
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"])
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6beff070>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '深圳'),
#   Text(-0.3399187231970732, 1.046162158377023, '广州'),
#   Text(-0.8899186574910393, -0.6465638275138399, '北京'),
#   Text(0.6465638691739385, -0.8899186272232008, '上海')])

# %%
# labels用于饼图标签的设置
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6ca99fa0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '深圳'),
#   Text(-0.3399187231970732, 1.046162158377023, '广州'),
#   Text(-0.8899186574910393, -0.6465638275138399, '北京'),
#   Text(0.6465638691739385, -0.8899186272232008, '上海')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10.00%'),
#   Text(-0.18541021265294902, 0.5706339045692853, '40.00%'),
#   Text(-0.48541017681329407, -0.3526711786439127, '20.00%'),
#   Text(0.35267120136760277, -0.48541016030356404, '30.00%')])

# %%
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], autopct='%.2f%%', explode=[0, 0,0.3, 0])
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6dbd0400>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '深圳'),
#   Text(-0.3399187231970732, 1.046162158377023, '广州'),
#   Text(-1.1326237458976862, -0.8228994168357963, '北京'),
#   Text(0.6465638691739385, -0.8899186272232008, '上海')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10.00%'),
#   Text(-0.18541021265294902, 0.5706339045692853, '40.00%'),
#   Text(-0.7281152652199411, -0.529006767965869, '20.00%'),
#   Text(0.35267120136760277, -0.48541016030356404, '30.00%')])

# %%
#以通过参数labeldistance和pctdistance进行标签和百分比显示的位置，1表示一个圆心到圆周的距离
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], autopct='%.2f%%', labeldistance=1.2, pctdistance=0.6)
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6dc25490>,
# ...
#  [Text(1.1412678178182487, 0.3708203985925972, '深圳'),
#   Text(-0.37082042530589804, 1.1412678091385706, '广州'),
#   Text(-0.9708203536265881, -0.7053423572878254, '北京'),
#   Text(0.7053424027352055, -0.9708203206071281, '上海')],
#  [Text(0.5706339089091244, 0.1854101992962986, '10.00%'),
#   Text(-0.18541021265294902, 0.5706339045692853, '40.00%'),
#   Text(-0.48541017681329407, -0.3526711786439127, '20.00%'),
#   Text(0.35267120136760277, -0.48541016030356404, '30.00%')])

# %%
#通过对wedgeprops参数设置还可以绘制圆环图
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], 
        autopct='%.2f%%', pctdistance=0.8,
        wedgeprops={'width': 0.3, 'linewidth': 2, 'edgecolor': 'w'})
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6dddda60>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '深圳'),
#   Text(-0.3399187231970732, 1.046162158377023, '广州'),
#   Text(-0.8899186574910393, -0.6465638275138399, '北京'),
#   Text(0.6465638691739385, -0.8899186272232008, '上海')],
#  [Text(0.7608452118788325, 0.24721359906173146, '10.00%'),
#   Text(-0.2472136168705987, 0.7608452060923805, '40.00%'),
#   Text(-0.6472135690843922, -0.4702282381918836, '20.00%'),
#   Text(0.4702282684901371, -0.6472135470714188, '30.00%')])

# %%
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], 
        autopct='%.2f%%', pctdistance=0.8,
        wedgeprops={'width': 0.3, 'linewidth': 2, 'edgecolor': 'b'})
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6dd85940>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '深圳'),
#   Text(-0.3399187231970732, 1.046162158377023, '广州'),
#   Text(-0.8899186574910393, -0.6465638275138399, '北京'),
#   Text(0.6465638691739385, -0.8899186272232008, '上海')],
#  [Text(0.7608452118788325, 0.24721359906173146, '10.00%'),
#   Text(-0.2472136168705987, 0.7608452060923805, '40.00%'),
#   Text(-0.6472135690843922, -0.4702282381918836, '20.00%'),
#   Text(0.4702282684901371, -0.6472135470714188, '30.00%')])

# %%
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], 
        autopct='%.2f%%', pctdistance=0.8,
        wedgeprops={'width': 0.3, 'linewidth': 8, 'edgecolor': 'w'})
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6df3fcd0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '深圳'),
#   Text(-0.3399187231970732, 1.046162158377023, '广州'),
#   Text(-0.8899186574910393, -0.6465638275138399, '北京'),
#   Text(0.6465638691739385, -0.8899186272232008, '上海')],
#  [Text(0.7608452118788325, 0.24721359906173146, '10.00%'),
#   Text(-0.2472136168705987, 0.7608452060923805, '40.00%'),
#   Text(-0.6472135690843922, -0.4702282381918836, '20.00%'),
#   Text(0.4702282684901371, -0.6472135470714188, '30.00%')])

# %%
plt.pie([1, 4, 2, 3], labels=["深圳", "广州", "北京", "上海"], 
        autopct='%.2f%%', pctdistance=0.8,
        wedgeprops={'width': 0.5, 'linewidth': 2, 'edgecolor': 'b'})
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6de8ebb0>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, '深圳'),
#   Text(-0.3399187231970732, 1.046162158377023, '广州'),
#   Text(-0.8899186574910393, -0.6465638275138399, '北京'),
#   Text(0.6465638691739385, -0.8899186272232008, '上海')],
#  [Text(0.7608452118788325, 0.24721359906173146, '10.00%'),
#   Text(-0.2472136168705987, 0.7608452060923805, '40.00%'),
#   Text(-0.6472135690843922, -0.4702282381918836, '20.00%'),
#   Text(0.4702282684901371, -0.6472135470714188, '30.00%')])

# %%
#散点图
import random

data_x = [random.randint(1, 100) for _ in range(100)]
data_y = [random.randint(1, 100) for _ in range(100)]
          
plt.scatter(data_x, data_y)

# %%
#散点图除了可以通过xy轴反映数据之外，还可以通过「点」的颜色和大小来反映数据，可以最多展示4个维度的数据；
import numpy as np

N = 30
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 

plt.scatter(x, y, 
            # 图形大小
            s=area, 
            # 颜色
            c=colors, 
            # 透明度
            alpha=0.2)

# %%
#除此之外，我们还可以通过Marker去设置标记点的形状，通过edgecolor去设置标记点的边框颜色；
plt.scatter(x, y, 
            # 图形大小
            s=area, 
            # 颜色
            c=colors, 
            # 透明度
            alpha=0.2,
            # 标记点形状
            marker='*',
            # 边框颜色
            edgecolor='blue'
            )

# %%
#作业1
plt.pie([56, 31, 20, 82, 72], labels=['华东', '华南', '华中', '西北', '东北'], 
        autopct='%.1f%%', pctdistance=0.8,explode=[0, 0,0,0.1, 0],
        wedgeprops={'width':0.5, 'linewidth': 4, 'edgecolor': 'w'})
# Out:
# ([<matplotlib.patches.Wedge at 0x21d6ec27610>,
# ...
#  [Text(0.8594246416263571, 0.6865779528687241, '华东'),
#   Text(-0.16488163653494248, 1.08757254743468, '华南'),
#   Text(-0.7612619270762039, 0.7940278826239193, '华中'),
#   Text(-1.095076406266012, -0.4907215752741226, '西北'),
#   Text(0.7121248374720811, -0.8383783250152417, '东北')],
#  [Text(0.625036103000987, 0.49932942026816296, '21.5%'),
#   Text(-0.11991391747995817, 0.7909618526797673, '11.9%'),
#   Text(-0.5536450378736028, 0.5774748237264867, '7.7%'),
#   Text(-0.8213073046995091, -0.3680411814555919, '31.4%'),
#   Text(0.517908972706968, -0.6097296909201758, '27.6%')])

# %%
#作业2
x = ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']  
y = [123, 145, 152, 182, 147, 138, 189, 201, 203, 211, 201, 182]
plt.plot(x, y, color=(1,0,0), linewidth=2, linestyle=':', marker='*', markersize=15)
